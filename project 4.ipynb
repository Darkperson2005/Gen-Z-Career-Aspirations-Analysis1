# %% [markdown]
# #EMPLOYEE CAREER ANALYSIS

# %% [markdown]
# OBJECTIVES:
# 1.what is the analysis of country?
# 2.what are the factors influncing the career aspiration of genZ?
# 3.how many wants to persue higher education outside india with their investment?
# 4.how likely genZ is to work for one company for three years or more?
# 5.what is the prefered working environment of genZ?

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
data=pd.read_csv("Genz.csv")

# %%
data.head()
# Out:
#   Your Current Country.  Your Current Zip Code / Pin Code Your Gender  \
# 0                 India                            273005        Male
# 1                 India                            851129        Male
# 2                 India                            123106      Female
# 3                 India                            834003        Male
# 4                 India                            301019      Female
#
#   Which of the below factors influence the most about your career aspirations ?  \
# 0       People who have changed the world for better
# 1       People who have changed the world for better
# 2                         Social Media like LinkedIn
# 3      People from my circle, but not family members
# 4             Influencers who had successful careers
#
#   Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.  \
# 0                       Yes, I will earn and do that
# ...

# %%
data.columns
# Out:
# Index(['Your Current Country.', 'Your Current Zip Code / Pin Code',
#        'Your Gender',
#        'Which of the below factors influence the most about your career aspirations ?',
#        'Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.',
#        'How likely is that you will work for one employer for 3 years or more ?',
#        'Would you work for a company whose mission is not clearly defined and publicly posted.',
#        'How likely would you work for a company whose mission is misaligned with their public actions or even their product ?',
#        'How likely would you work for a company whose mission is not bringing social impact ?',
#        'What is the most preferred working environment for you.',
#        'Which of the below Employers would you work with.',
#        'Which type of learning environment that you are most likely to work in ?',
# ...

# %%
#1.what is the analysis of country? percentage of people of any country in pie graph with labelling
country=data['Your Current Country.'].value_counts()
label=country.index
counts=country.values
colors=['red','lightgreen']
fig=go.Figure(data=[go.Pie(labels=label,values=counts)])
fig.update_layout(title_text='current country')
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=30, 
                  marker=dict(colors=colors, line=dict(color='black', width=1)))
fig.show()

# %%
country
# Out:
# Your Current Country.
# India                       231
# Germany                       2
# United Arab Emirates          1
# United States of America      1
# Name: count, dtype: int64

# %% [markdown]
#  #2.what are the factors influncing the career aspiration of genZ?

# %%
question1 =data['Which of the below factors influence the most about your career aspirations ?'].value_counts()
label=question1.index
counts=question1.values
colors=['gold', 'lightgreen']
fig=go.Figure(data=[go.Pie(labels=label, values=counts)])
fig.update_layout(title_text='Factors influencing career aspirations') #for title
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=10, 
                  marker=dict(colors=colors, line=dict(color='black', width=1))) #for boundary and scaling
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="09aa832c-fa2c-4e57-851d-693acfe4fd58" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("09aa832c-fa2c-4e57-851d-693acfe4fd58")) {                    Plotly.newPlot(                        "09aa832c-fa2c-4e57-851d-693acfe4fd58",                        [{"labels":["My Parents","People who have changed the world for better","People from my circle, but not family members","Influencers who had successful careers","Social Media like LinkedIn"],"values":{"dtype":"i1","bdata":"TzknJRc="},"type":"pie","te
# ...

# %% [markdown]
# #3.how many wants to persue higher education outside india with their investment?

# %%
question2=data['Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.'].value_counts()
label=question2.index
counts=question2.values
colors=['orange', 'green']
fig=go.Figure(data=[go.Pie(labels=label, values=counts)])
fig.update_layout(title_text='pursue a Higher Education / Post Graduation outside of Indias') #for title
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=10, 
                  marker=dict(colors=colors, line=dict(color='black', width=1))) #for boundary and scaling
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="bdda4ca4-95bb-450b-8120-2f10dc72a64c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bdda4ca4-95bb-450b-8120-2f10dc72a64c")) {                    Plotly.newPlot(                        "bdda4ca4-95bb-450b-8120-2f10dc72a64c",                        [{"labels":["Yes, I will earn and do that","No I would not be pursuing Higher Education outside of India","No, But if someone could bare the cost I will"],"values":{"dtype":"i1","bdata":"bkE8"},"type":"pie","textfont":{"size":10},"marker":{"line":{"c
# ...

# %%
question2
# Out:
# Would you definitely pursue a Higher Education / Post Graduation outside of India ? If only you have to self sponsor it.
# Yes, I will earn and do that                                    110
# No I would not be pursuing Higher Education outside of India     65
# No, But if someone could bare the cost I will                    60
# Name: count, dtype: int64

# %% [markdown]
# # 4.how likely genZ is to work for one company for three years or more?

# %%
question3 =data['How likely is that you will work for one employer for 3 years or more ?'].value_counts()
label=question3.index
counts=question3.values
colors=['red', 'green']
fig=go.Figure(data=[go.Pie(labels=label, values=counts)])
fig.update_layout(title_text='How likely is that you will work in one company') #for title
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=10, 
                  marker=dict(colors=colors, line=dict(color='black', width=1))) #for boundary and scaling
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="7778fae3-7647-4b37-80a3-6ff8ef72685e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7778fae3-7647-4b37-80a3-6ff8ef72685e")) {                    Plotly.newPlot(                        "7778fae3-7647-4b37-80a3-6ff8ef72685e",                        [{"labels":["This will be hard to do, but if it is the right company I would try","Will work for 3 years or more","No way, 3 years with one employer is crazy"],"values":{"dtype":"i2","bdata":"iwBPABEA"},"type":"pie","textfont":{"size":10},"marker":{"
# ...

# %%
question3.index
# Out:
# Index(['This will be hard to do, but if it is the right company I would try',
#        'Will work for 3 years or more',
#        'No way, 3 years with one employer is crazy'],
#       dtype='object', name='How likely is that you will work for one employer for 3 years or more ?')

# %%
question3.count
# Out:
# <bound method Series.count of How likely is that you will work for one employer for 3 years or more ?
# This will be hard to do, but if it is the right company I would try    139
# Will work for 3 years or more                                           79
# No way, 3 years with one employer is crazy                              17
# Name: count, dtype: int64>

# %% [markdown]
#  #5.what is the prefered working environment of genZ?

# %%
question4 =data['What is the most preferred working environment for you.'].value_counts()
label=question4.index
counts=question4.values
colors=['red', 'green']
fig=go.Figure(data=[go.Pie(labels=label, values=counts)])
fig.update_layout(title_text='most preferred working environmen for employes') #for title
fig.update_traces(hoverinfo='label+value', textinfo='percent', textfont_size=10, 
                  marker=dict(colors=colors, line=dict(color='black', width=1))) #for boundary and scaling
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="8803fa4a-5a12-4337-a968-cd0fe84f9981" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8803fa4a-5a12-4337-a968-cd0fe84f9981")) {                    Plotly.newPlot(                        "8803fa4a-5a12-4337-a968-cd0fe84f9981",                        [{"labels":["Fully Remote with Options to travel as and when needed","Hybrid Working Environment with less than 15 days a month at office","Every Day Office Environment","Hybrid Working Environment with less than 10 days a month at office","Hybrid Wo
# ...

# %%
question4
# Out:
# What is the most preferred working environment for you.
# Fully Remote with Options to travel as and when needed                 60
# Hybrid Working Environment with less than 15 days a month at office    57
# Every Day Office Environment                                           50
# Hybrid Working Environment with less than 10 days a month at office    31
# Hybrid Working Environment with less than 3 days a month at office     26
# Fully Remote with No option to visit offices                           11
# Name: count, dtype: int64

# %%
question4.index
# Out:
# Index(['Fully Remote with Options to travel as and when needed',
#        'Hybrid Working Environment with less than 15 days a month at office',
#        'Every Day Office Environment',
#        'Hybrid Working Environment with less than 10 days a month at office',
#        'Hybrid Working Environment with less than 3 days a month at office',
#        'Fully Remote with No option to visit offices'],
#       dtype='object', name='What is the most preferred working environment for you.')

# %%
question4.count
# Out:
# <bound method Series.count of What is the most preferred working environment for you.
# Fully Remote with Options to travel as and when needed                 60
# Hybrid Working Environment with less than 15 days a month at office    57
# Every Day Office Environment                                           50
# Hybrid Working Environment with less than 10 days a month at office    31
# Hybrid Working Environment with less than 3 days a month at office     26
# Fully Remote with No option to visit offices                           11
# Name: count, dtype: int64>
